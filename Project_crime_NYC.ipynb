# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ###Reading my csv Data

# %%
missing_values = ['n/a','na','NaN','--','(null)']

# %%
df = pd.read_csv('https://data.cityofnewyork.us/api/views/uip8-fykc/rows.csv?accessType=DOWNLOAD', na_values=missing_values)

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0            TRESPASS 2, CRIMINAL  352.0
# 1       238682242  01/05/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 2       238723993  01/06/2022  153.0                          RAPE 3  104.0
# 3       238821533  01/08/2022    NaN                             NaN    NaN
# 4       239029586  01/12/2022    NaN                             NaN    NaN
# ...           ...         ...    ...                             ...    ...
# 93233   245643921  05/25/2022  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 93234   244421351  05/01/2022  817.0   TORTURE/INJURE ANIMAL CRUELTY  364.0
# 93235   245240736  05/18/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 93236   246474038  06/11/2022  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 93237   245621424  05/25/2022  101.0                       ASSAULT 3  344.0
#
# ...

# %% [markdown]
# ###Getting info of my data

# %%
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   238552639  01/03/2022  205.0            TRESPASS 2, CRIMINAL  352.0
# 1   238682242  01/05/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 2   238723993  01/06/2022  153.0                          RAPE 3  104.0
# 3   238821533  01/08/2022    NaN                             NaN    NaN
# 4   239029586  01/12/2022    NaN                             NaN    NaN
#
#            OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0  CRIMINAL TRESPASS  PL 1401501          M           K               75
# 1            ROBBERY  PL 160050H          F           K               75
# 2               RAPE  PL 1302503          F           K               77
# 3                NaN  CPL5700600          9           Q              113
# 4                NaN  CPL5700600          9           Q              113
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  \
# ...

# %%
df.tail()
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 93233   245643921  05/25/2022  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 93234   244421351  05/01/2022  817.0   TORTURE/INJURE ANIMAL CRUELTY  364.0
# 93235   245240736  05/18/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 93236   246474038  06/11/2022  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 93237   245621424  05/25/2022  101.0                       ASSAULT 3  344.0
#
#                                   OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 93233                         PETIT LARCENY  PL 1552500          M
# 93234  AGRICULTURE & MRKTS LAW-UNCLASSIFIED  AM 0353000          M
# 93235                               ROBBERY  PL 160102A          F
# 93236                     DANGEROUS WEAPONS  PL 265031B          F
# 93237          ASSAULT 3 & RELATED OFFENSES  PL 1200001          M
#
#       ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93238 entries, 0 to 93237
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ARREST_KEY                93238 non-null  int64
#  1   ARREST_DATE               93238 non-null  object
#  2   PD_CD                     93005 non-null  float64
#  3   PD_DESC                   92934 non-null  object
#  4   KY_CD                     92934 non-null  float64
#  5   OFNS_DESC                 92934 non-null  object
#  6   LAW_CODE                  93238 non-null  object
#  7   LAW_CAT_CD                92327 non-null  object
#  8   ARREST_BORO               93238 non-null  object
#  9   ARREST_PRECINCT           93238 non-null  int64
#  10  JURISDICTION_CODE         93238 non-null  int64
#  11  AGE_GROUP                 93238 non-null  object
#  12  PERP_SEX                  93238 non-null  object
# ...

# %%
df.shape
# Out:
# (93238, 19)

# %%
df.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
df.columns
# Out:
# Index(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD', 'OFNS_DESC',
#        'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO', 'ARREST_PRECINCT',
#        'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'New Georeferenced Column'],
#       dtype='object')

# %%
df.describe()
# Out:
#          ARREST_KEY         PD_CD  PD_DESC         KY_CD  ARREST_PRECINCT  \
# count  9.323800e+04  93238.000000      0.0  92934.000000     93238.000000
# mean   2.430966e+08    405.266050      NaN    247.769320        62.918864
# std    2.534191e+06    270.645663      NaN    151.538327        35.042096
# min    2.384924e+08     15.000000      NaN    101.000000         1.000000
# 25%    2.409671e+08    113.000000      NaN    111.000000        40.000000
# 50%    2.431381e+08    339.000000      NaN    235.000000        62.000000
# 75%    2.452604e+08    681.000000      NaN    344.000000       100.000000
# max    2.474175e+08    997.000000      NaN    995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD      Latitude  \
# count       93238.000000  9.323800e+04   93238.000000  93238.000000
# mean            0.965315  1.004903e+06  208473.045432     40.738840
# std             8.108805  2.124446e+04   29546.933230      0.081104
# ...

# %% [markdown]
# ###Rename the Columns

# %%
df.rename(columns={
        'PERP_SEX':'SEX','PERP_RACE':'RACE'}, inplace=True) # to rename the columns

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0            TRESPASS 2, CRIMINAL  352.0
# 1       238682242  01/05/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 2       238723993  01/06/2022  153.0                          RAPE 3  104.0
# 3       238821533  01/08/2022    NaN                             NaN    NaN
# 4       239029586  01/12/2022    NaN                             NaN    NaN
# ...           ...         ...    ...                             ...    ...
# 93233   245643921  05/25/2022  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 93234   244421351  05/01/2022  817.0   TORTURE/INJURE ANIMAL CRUELTY  364.0
# 93235   245240736  05/18/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 93236   246474038  06/11/2022  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 93237   245621424  05/25/2022  101.0                       ASSAULT 3  344.0
#
# ...

# %% [markdown]
# ###REPLACE VALUES IN ROWS

# %%
df['ARREST_BORO'] = df['ARREST_BORO'].replace(['K','Q','B','S','M'],['BROOKLYN','QUEENS','BRONX','STATE ISLAND','MANHATTAN'])

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0            TRESPASS 2, CRIMINAL  352.0
# 1       238682242  01/05/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 2       238723993  01/06/2022  153.0                          RAPE 3  104.0
# 3       238821533  01/08/2022    NaN                             NaN    NaN
# 4       239029586  01/12/2022    NaN                             NaN    NaN
# ...           ...         ...    ...                             ...    ...
# 93233   245643921  05/25/2022  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 93234   244421351  05/01/2022  817.0   TORTURE/INJURE ANIMAL CRUELTY  364.0
# 93235   245240736  05/18/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 93236   246474038  06/11/2022  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 93237   245621424  05/25/2022  101.0                       ASSAULT 3  344.0
#
# ...

# %% [markdown]
# ###Let's work with the missing values

# %%
df.isnull()
# Out:
#        ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# 0           False        False  False    False  False      False     False
# 1           False        False  False    False  False      False     False
# 2           False        False  False    False  False      False     False
# 3           False        False   True     True   True       True     False
# 4           False        False   True     True   True       True     False
# ...           ...          ...    ...      ...    ...        ...       ...
# 93233       False        False  False    False  False      False     False
# 93234       False        False  False    False  False      False     False
# 93235       False        False  False    False  False      False     False
# 93236       False        False  False    False  False      False     False
# 93237       False        False  False    False  False      False     False
#
# ...

# %%
df.isnull().sum()
# Out:
# ARREST_KEY                    0
# ARREST_DATE                   0
# PD_CD                       233
# PD_DESC                     304
# KY_CD                       304
# OFNS_DESC                   304
# LAW_CODE                      0
# LAW_CAT_CD                  911
# ARREST_BORO                   0
# ARREST_PRECINCT               0
# JURISDICTION_CODE             0
# AGE_GROUP                     0
# SEX                           0
# RACE                          0
# X_COORD_CD                    0
# Y_COORD_CD                    0
# Latitude                      0
# Longitude                     0
# New Georeferenced Column      0
# dtype: int64

# %%
df['PD_CD']=pd.to_numeric(df['PD_CD'],errors='coerce')

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0            TRESPASS 2, CRIMINAL  352.0
# 1       238682242  01/05/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 2       238723993  01/06/2022  153.0                          RAPE 3  104.0
# 3       238821533  01/08/2022    NaN                             NaN    NaN
# 4       239029586  01/12/2022    NaN                             NaN    NaN
# ...           ...         ...    ...                             ...    ...
# 93233   245643921  05/25/2022  339.0  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 93234   244421351  05/01/2022  817.0   TORTURE/INJURE ANIMAL CRUELTY  364.0
# 93235   245240736  05/18/2022  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 93236   246474038  06/11/2022  792.0        WEAPONS POSSESSION 1 & 2  118.0
# 93237   245621424  05/25/2022  101.0                       ASSAULT 3  344.0
#
# ...

# %%
df['PD_DESC']=pd.to_numeric(df['PD_DESC'],errors='coerce')

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0      NaN  352.0
# 1       238682242  01/05/2022  397.0      NaN  105.0
# 2       238723993  01/06/2022  153.0      NaN  104.0
# 3       238821533  01/08/2022    NaN      NaN    NaN
# 4       239029586  01/12/2022    NaN      NaN    NaN
# ...           ...         ...    ...      ...    ...
# 93233   245643921  05/25/2022  339.0      NaN  341.0
# 93234   244421351  05/01/2022  817.0      NaN  364.0
# 93235   245240736  05/18/2022  397.0      NaN  105.0
# 93236   246474038  06/11/2022  792.0      NaN  118.0
# 93237   245621424  05/25/2022  101.0      NaN  344.0
#
#                                   OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                         CRIMINAL TRESPASS  PL 1401501          M
# 1                                   ROBBERY  PL 160050H          F
# 2                                      RAPE  PL 1302503          F
# ...

# %% [markdown]
# ###Imputation of the missing data

# %%
median_pd_cd = df['PD_CD'].median()

# %%
median_pd_cd
# Out:
# 339.0

# %%
median_PD_DESC = df['PD_DESC'].median()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/lib/nanfunctions.py:1117: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)

# %%
median_PD_DESC
# Out:
# nan

# %% [markdown]
# ###Filling the Dataset

# %%
df['PD_CD'].fillna(median_pd_cd,inplace=True)

# %%
df
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  PD_DESC  KY_CD  \
# 0       238552639  01/03/2022  205.0      NaN  352.0
# 1       238682242  01/05/2022  397.0      NaN  105.0
# 2       238723993  01/06/2022  153.0      NaN  104.0
# 3       238821533  01/08/2022  339.0      NaN    NaN
# 4       239029586  01/12/2022  339.0      NaN    NaN
# ...           ...         ...    ...      ...    ...
# 93233   245643921  05/25/2022  339.0      NaN  341.0
# 93234   244421351  05/01/2022  817.0      NaN  364.0
# 93235   245240736  05/18/2022  397.0      NaN  105.0
# 93236   246474038  06/11/2022  792.0      NaN  118.0
# 93237   245621424  05/25/2022  101.0      NaN  344.0
#
#                                   OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 0                         CRIMINAL TRESPASS  PL 1401501          M
# 1                                   ROBBERY  PL 160050H          F
# 2                                      RAPE  PL 1302503          F
# ...

# %% [markdown]
# ###Analysis  of my dataset

# %%
df.groupby('ARREST_BORO').count()
# Out:
#               ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# ARREST_BORO
# BRONX              21198        21198  21198        0  21176      21176
# BROOKLYN           25431        25431  25431        0  25404      25404
# MANHATTAN          22997        22997  22997        0  22981      22981
# QUEENS             19416        19416  19416        0  19181      19181
# STATE ISLAND        4196         4196   4196        0   4192       4192
#
#               LAW_CODE  LAW_CAT_CD  ARREST_PRECINCT  JURISDICTION_CODE  \
# ARREST_BORO
# BRONX            21198       21014            21198              21198
# BROOKLYN         25431       25301            25431              25431
# MANHATTAN        22997       22656            22997              22997
# QUEENS           19416       19183            19416              19416
# STATE ISLAND      4196        4173             4196               4196
#
#               AGE_GROUP    SEX   RACE  X_COORD_CD  Y_COORD_CD  Latitude  \
# ...

# %%
df['ARREST_BORO'].value_counts()
# Out:
# BROOKLYN        25431
# MANHATTAN       22997
# BRONX           21198
# QUEENS          19416
# STATE ISLAND     4196
# Name: ARREST_BORO, dtype: int64

# %%
df['ARREST_BORO'].value_counts().plot(kind='bar')

# %%
df.groupby('OFNS_DESC').count()
# Out:
#                                       ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  \
# OFNS_DESC
# ADMINISTRATIVE CODE                           64           64     64        0
# ADMINISTRATIVE CODES                           1            1      1        0
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED          37           37     37        0
# ALCOHOLIC BEVERAGE CONTROL LAW                74           74     74        0
# ANTICIPATORY OFFENSES                         15           15     15        0
# ...                                          ...          ...    ...      ...
# THEFT OF SERVICES                             93           93     93        0
# THEFT-FRAUD                                  107          107    107        0
# UNAUTHORIZED USE OF A VEHICLE                255          255    255        0
# UNLAWFUL POSS. WEAP. ON SCHOOL                 1            1      1        0
# VEHICLE AND TRAFFIC LAWS                    2993         2993   2993        0
#
# ...

# %%
df['OFNS_DESC'].value_counts()
# Out:
# ASSAULT 3 & RELATED OFFENSES      15402
# PETIT LARCENY                      9944
# FELONY ASSAULT                     9128
# MISCELLANEOUS PENAL LAW            6187
# DANGEROUS DRUGS                    5256
#                                   ...
# LOITERING/GAMBLING (CARDS, DIC        3
# NEW YORK CITY HEALTH CODE             2
# PARKING OFFENSES                      2
# UNLAWFUL POSS. WEAP. ON SCHOOL        1
# ADMINISTRATIVE CODES                  1
# Name: OFNS_DESC, Length: 62, dtype: int64

# %%
df.groupby('AGE_GROUP').count()
# Out:
#            ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# AGE_GROUP
# 18-24           16255        16255  16255        0  16185      16185
# 25-44           53758        53758  53758        0  53571      53571
# 45-64           18491        18491  18491        0  18450      18450
# 65+              1350         1350   1350        0   1344       1344
# <18              3384         3384   3384        0   3384       3384
#
#            LAW_CODE  LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  \
# AGE_GROUP
# 18-24         16255       16110        16255            16255
# 25-44         53758       53168        53758            53758
# 45-64         18491       18329        18491            18491
# 65+            1350        1337         1350             1350
# <18            3384        3383         3384             3384
#
#            JURISDICTION_CODE    SEX   RACE  X_COORD_CD  Y_COORD_CD  Latitude  \
# AGE_GROUP
# ...

# %%
df['AGE_GROUP'].value_counts()
# Out:
# 25-44    53758
# 45-64    18491
# 18-24    16255
# <18       3384
# 65+       1350
# Name: AGE_GROUP, dtype: int64

# %%
df['AGE_GROUP'].value_counts().plot(kind='bar')

# %%
df.groupby('SEX').count()
# Out:
#      ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# SEX
# F         16269        16269  16269        0  16218      16218     16269
# M         76969        76969  76969        0  76716      76716     76969
#
#      LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  AGE_GROUP  \
# SEX
# F         16190        16269            16269              16269      16269
# M         76137        76969            76969              76969      76969
#
#       RACE  X_COORD_CD  Y_COORD_CD  Latitude  Longitude  \
# SEX
# F    16269       16269       16269     16269      16269
# M    76969       76969       76969     76969      76969
#
#      New Georeferenced Column
# SEX
# F                       16269
# M                       76969

# %%
df['SEX'].value_counts()
# Out:
# M    76969
# F    16269
# Name: SEX, dtype: int64

# %%
df['SEX'].value_counts().plot(kind='bar')

# %%
df.groupby('RACE').count()
# Out:
#                                 ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  \
# RACE
# AMERICAN INDIAN/ALASKAN NATIVE         239          239    239        0
# ASIAN / PACIFIC ISLANDER              5006         5006   5006        0
# BLACK                                46114        46114  46114        0
# BLACK HISPANIC                        8206         8206   8206        0
# UNKNOWN                                331          331    331        0
# WHITE                                 9962         9962   9962        0
# WHITE HISPANIC                       23380        23380  23380        0
#
#                                 KY_CD  OFNS_DESC  LAW_CODE  LAW_CAT_CD  \
# RACE
# AMERICAN INDIAN/ALASKAN NATIVE    239        239       239         238
# ASIAN / PACIFIC ISLANDER         4978       4978      5006        4938
# BLACK                           45976      45976     46114       45791
# BLACK HISPANIC                   8179       8179      8206        8095
# ...

# %%
df['RACE'].value_counts()
# Out:
# BLACK                             46114
# WHITE HISPANIC                    23380
# WHITE                              9962
# BLACK HISPANIC                     8206
# ASIAN / PACIFIC ISLANDER           5006
# UNKNOWN                             331
# AMERICAN INDIAN/ALASKAN NATIVE      239
# Name: RACE, dtype: int64

# %%
df['RACE'].value_counts().plot(kind='bar')

# %%
df.groupby(['ARREST_BORO','RACE']).count()
# Out:
#                                              ARREST_KEY  ARREST_DATE  PD_CD  \
# ARREST_BORO  RACE
# BRONX        AMERICAN INDIAN/ALASKAN NATIVE          38           38     38
#              ASIAN / PACIFIC ISLANDER               286          286    286
#              BLACK                                10173        10173  10173
#              BLACK HISPANIC                        3676         3676   3676
#              UNKNOWN                                 65           65     65
#              WHITE                                  687          687    687
#              WHITE HISPANIC                        6273         6273   6273
# BROOKLYN     AMERICAN INDIAN/ALASKAN NATIVE          56           56     56
#              ASIAN / PACIFIC ISLANDER              1041         1041   1041
#              BLACK                                14974        14974  14974
#              BLACK HISPANIC                        1207         1207   1207
# ...

# %% [markdown]
# ###Picking Queens  as my initial comparison point

# %%
df_Queens = df[df['ARREST_BORO']== 'QUEENS']

# %%
df_Queens
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  PD_DESC  KY_CD  \
# 3       238821533  01/08/2022  339.0      NaN    NaN
# 4       239029586  01/12/2022  339.0      NaN    NaN
# 6       239406147  01/20/2022  339.0      NaN    NaN
# 9       239828064  01/28/2022  339.0      NaN    NaN
# 10      241020842  02/21/2022  339.0      NaN    NaN
# ...           ...         ...    ...      ...    ...
# 93212   243839848  04/19/2022  779.0      NaN  126.0
# 93215   244943451  05/12/2022  729.0      NaN  113.0
# 93218   243763744  04/17/2022  802.0      NaN  346.0
# 93221   246117976  06/04/2022  339.0      NaN  341.0
# 93223   245425415  05/21/2022  782.0      NaN  236.0
#
#                             OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 3                                 NaN  CPL5700600          9      QUEENS
# 4                                 NaN  CPL5700600          9      QUEENS
# 6                                 NaN  CPL5700600          9      QUEENS
# ...

# %% [markdown]
# ###Analysis for the selected school

# %%
df_Queens['ARREST_BORO'].describe()
# Out:
# count      19416
# unique         1
# top       QUEENS
# freq       19416
# Name: ARREST_BORO, dtype: object

# %%
df_Queens.groupby('ARREST_BORO').count()
# Out:
#              ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# ARREST_BORO
# QUEENS            19416        19416  19416        0  19181      19181
#
#              LAW_CODE  LAW_CAT_CD  ARREST_PRECINCT  JURISDICTION_CODE  \
# ARREST_BORO
# QUEENS          19416       19183            19416              19416
#
#              AGE_GROUP    SEX   RACE  X_COORD_CD  Y_COORD_CD  Latitude  \
# ARREST_BORO
# QUEENS           19416  19416  19416       19416       19416     19416
#
#              Longitude  New Georeferenced Column
# ARREST_BORO
# QUEENS           19416                     19416

# %%
df_Queens['ARREST_BORO'].value_counts()
# Out:
# QUEENS    19416
# Name: ARREST_BORO, dtype: int64

# %%
df_Queens.groupby('SEX').count()
# Out:
#      ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# SEX
# F          3449         3449   3449        0   3414       3414      3449
# M         15967        15967  15967        0  15767      15767     15967
#
#      LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  AGE_GROUP  \
# SEX
# F          3432         3449             3449               3449       3449
# M         15751        15967            15967              15967      15967
#
#       RACE  X_COORD_CD  Y_COORD_CD  Latitude  Longitude  \
# SEX
# F     3449        3449        3449      3449       3449
# M    15967       15967       15967     15967      15967
#
#      New Georeferenced Column
# SEX
# F                        3449
# M                       15967

# %%
df_Queens['SEX'].value_counts()
# Out:
# M    15967
# F     3449
# Name: SEX, dtype: int64

# %%
df_Queens['SEX'].value_counts().plot(kind='bar')

# %%
df_Queens['SEX'].value_counts().mean()
# Out:
# 9708.0

# %%
df_Queens['SEX'].value_counts().min()
# Out:
# 3449

# %%
df_Queens['SEX'].value_counts().max()
# Out:
# 15967

# %%
df_Queens.groupby('OFNS_DESC').count()
# Out:
#                                       ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  \
# OFNS_DESC
# ADMINISTRATIVE CODE                           13           13     13        0
# ADMINISTRATIVE CODES                           1            1      1        0
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED           7            7      7        0
# ALCOHOLIC BEVERAGE CONTROL LAW                18           18     18        0
# ANTICIPATORY OFFENSES                          4            4      4        0
# ARSON                                         11           11     11        0
# ASSAULT 3 & RELATED OFFENSES                3472         3472   3472        0
# BURGLAR'S TOOLS                               61           61     61        0
# BURGLARY                                     409          409    409        0
# CHILD ABANDONMENT/NON SUPPORT                  3            3      3        0
# CRIMINAL MISCHIEF & RELATED OF              1108         1108   1108        0
# ...

# %%
df_Queens['OFNS_DESC'].value_counts()
# Out:
# ASSAULT 3 & RELATED OFFENSES            3472
# FELONY ASSAULT                          2025
# MISCELLANEOUS PENAL LAW                 1803
# PETIT LARCENY                           1510
# CRIMINAL MISCHIEF & RELATED OF          1108
# ROBBERY                                  899
# DANGEROUS WEAPONS                        727
# DANGEROUS DRUGS                          724
# GRAND LARCENY                            721
# VEHICLE AND TRAFFIC LAWS                 717
# SEX CRIMES                               679
# FORGERY                                  625
# OFFENSES INVOLVING FRAUD                 449
# OFFENSES AGAINST PUBLIC ADMINI           433
# BURGLARY                                 409
# OFF. AGNST PUB ORD SENSBLTY &            404
# INTOXICATED & IMPAIRED DRIVING           376
# POSSESSION OF STOLEN PROPERTY            290
# FOR OTHER AUTHORITIES                    233
# OTHER TRAFFIC INFRACTION                 218
# GRAND LARCENY OF MOTOR VEHICLE           182
# ...

# %%
df_Queens.groupby('AGE_GROUP').count()
# Out:
#            ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# AGE_GROUP
# 18-24            3425         3425   3425        0   3376       3376
# 25-44           11465        11465  11465        0  11321      11321
# 45-64            3540         3540   3540        0   3502       3502
# 65+               330          330    330        0    326        326
# <18               656          656    656        0    656        656
#
#            LAW_CODE  LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  \
# AGE_GROUP
# 18-24          3425        3406         3425             3425
# 25-44         11465       11272        11465            11465
# 45-64          3540        3519         3540             3540
# 65+             330         330          330              330
# <18             656         656          656              656
#
#            JURISDICTION_CODE    SEX   RACE  X_COORD_CD  Y_COORD_CD  Latitude  \
# AGE_GROUP
# ...

# %%
df_Queens['AGE_GROUP'].value_counts()
# Out:
# 25-44    11465
# 45-64     3540
# 18-24     3425
# <18        656
# 65+        330
# Name: AGE_GROUP, dtype: int64

# %%
df_Queens['AGE_GROUP'].value_counts().plot(kind='bar')

# %%
df_Queens.groupby('RACE').count()
# Out:
#                                 ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  \
# RACE
# AMERICAN INDIAN/ALASKAN NATIVE          94           94     94        0
# ASIAN / PACIFIC ISLANDER              2793         2793   2793        0
# BLACK                                 7445         7445   7445        0
# BLACK HISPANIC                         931          931    931        0
# UNKNOWN                                 69           69     69        0
# WHITE                                 2112         2112   2112        0
# WHITE HISPANIC                        5972         5972   5972        0
#
#                                 KY_CD  OFNS_DESC  LAW_CODE  LAW_CAT_CD  \
# RACE
# AMERICAN INDIAN/ALASKAN NATIVE     94         94        94          94
# ASIAN / PACIFIC ISLANDER         2770       2770      2793        2771
# BLACK                            7342       7342      7445        7377
# BLACK HISPANIC                    908        908       931         920
# ...

# %%
df_Queens['RACE'].value_counts()
# Out:
# BLACK                             7445
# WHITE HISPANIC                    5972
# ASIAN / PACIFIC ISLANDER          2793
# WHITE                             2112
# BLACK HISPANIC                     931
# AMERICAN INDIAN/ALASKAN NATIVE      94
# UNKNOWN                             69
# Name: RACE, dtype: int64

# %%
df_Queens['RACE'].value_counts().plot(kind='bar')

# %%
mean_arrest_per_race_Q=df_Queens['RACE'].value_counts().mean()

# %%
mean_arrest_per_race_Q
# Out:
# 2773.714285714286

# %%
mean_arrest_per_sex_Q =df_Queens['SEX'].value_counts().mean()

# %%
mean_arrest_per_sex_Q
# Out:
# 9708.0

# %%
mean_arrest_per_OFNS=df_Queens['OFNS_DESC'].value_counts().mean()

# %%
mean_arrest_per_OFNS
# Out:
# 336.50877192982455

# %%
mean_queens = mean_arrest_per_OFNS, mean_arrest_per_race_Q,mean_arrest_per_sex_Q

# %%
mean_queens
# Out:
# (336.50877192982455, 2773.714285714286, 9708.0)

# %% [markdown]
# ### Creating a DataFrame

# %%
data_queens= pd.DataFrame(
    { 
    'Borough':['Queens'],  
    'mean_Sex':[mean_arrest_per_sex_Q],
    'mean_race':[mean_arrest_per_race_Q],
    'mean_Ofns':[mean_arrest_per_OFNS]
    } 
)

# %%
data_queens
# Out:
#   Borough  mean_Sex    mean_race   mean_Ofns
# 0  Queens    9708.0  2773.714286  336.508772

# %%
data_queens['Index']=1

# %%
data_queens
# Out:
#   Borough  mean_Sex    mean_race   mean_Ofns  Index
# 0  Queens    9708.0  2773.714286  336.508772      1

# %% [markdown]
# ###Filtering the columns of the selected School

# %% [markdown]
# ###The comparison between Queens and other Borough

# %% [markdown]
# Selection of all the School "James Madison School"

# %%
df_Bronx= df[df['ARREST_BORO']== 'BRONX']

# %%
df_Bronx
# Out:
#        ARREST_KEY ARREST_DATE  PD_CD  PD_DESC  KY_CD  \
# 15      240475883  02/11/2022  157.0      NaN  104.0
# 17      239832512  01/28/2022  263.0      NaN  114.0
# 21      241656686  03/06/2022  244.0      NaN  107.0
# 23      241671896  03/06/2022  157.0      NaN  104.0
# 30      244125280  04/25/2022  397.0      NaN  105.0
# ...           ...         ...    ...      ...    ...
# 93203   245931724  06/01/2022  478.0      NaN  343.0
# 93206   244006095  04/22/2022  397.0      NaN  105.0
# 93233   245643921  05/25/2022  339.0      NaN  341.0
# 93234   244421351  05/01/2022  817.0      NaN  364.0
# 93236   246474038  06/11/2022  792.0      NaN  118.0
#
#                                   OFNS_DESC    LAW_CODE LAW_CAT_CD  \
# 15                                     RAPE  PL 1303501          F
# 17                                    ARSON  PL 1501001          F
# 21                                 BURGLARY  PL 1402501          F
# ...

# %%
mean_arrest_per_race_B=df_Bronx['RACE'].value_counts().mean()

# %%
mean_arrest_per_race_B
# Out:
# 3028.285714285714

# %%
mean_arrest_per_sex_B =df_Bronx['SEX'].value_counts().mean()

# %%
mean_arrest_per_sex_B
# Out:
# 10599.0

# %%
mean_arrest_per_OFNS_B =df_Bronx['OFNS_DESC'].value_counts().mean()

# %%
mean_arrest_per_OFNS_B
# Out:
# 378.14285714285717

# %%
mean_Bronx = mean_arrest_per_OFNS_B,mean_arrest_per_race_B,mean_arrest_per_sex_B

# %%
mean_Bronx
# Out:
# (378.14285714285717, 3028.285714285714, 10599.0)

# %%
data_Bronx= pd.DataFrame(
    { 
    'Borough':['Bronx'],  
    'mean_Sex':[mean_arrest_per_sex_B],
    'mean_race':[mean_arrest_per_race_B],
    'mean_Ofns':[mean_arrest_per_OFNS_B]
    } 
)

# %%
data_Bronx
# Out:
#   Borough  mean_Sex    mean_race   mean_Ofns
# 0   Bronx   10599.0  3028.285714  378.142857

# %%
data_Bronx['Index']=1

# %%
data_Bronx
# Out:
#   Borough  mean_Sex    mean_race   mean_Ofns  Index
# 0   Bronx   10599.0  3028.285714  378.142857      1

# %%
data_comparison =pd.merge(data_queens,data_Bronx, on='Index')

# %%
data_comparison
# Out:
#   Borough_x  mean_Sex_x  mean_race_x  mean_Ofns_x  Index Borough_y  \
# 0    Queens      9708.0  2773.714286   336.508772      1     Bronx
#
#    mean_Sex_y  mean_race_y  mean_Ofns_y
# 0     10599.0  3028.285714   378.142857

# %%
JM_score_per_year=df_JamesMadisonHS[['Year','Total Tested','Number Scoring CR','Percent Scoring CR']]

# %%
JM_score_per_year

# %%
JM=df_JamesMadisonHS[['School Name','Year','Total Tested','Number Scoring CR','Percent Scoring CR']].value_counts()

# %%
FL=df_francis_lewisHS[['School Name','Year','Total Tested','Number Scoring CR','Percent Scoring CR']].value_counts()

# %%
FL

# %%
JM

# %%
merge= pd.merge(FL_score_per_year, JM_score_per_year, on='Year')

# %%
merge

# %%
data_comparison.rename(columns={
        'mean_Sex_x':'Arrest_sex_Q','mean_race_x':'Arrest_Race_Q','mean_Ofns_x':'Arrest_type_Q','mean_Sex_y':'Arrest_sex_B','mean_race_y':'Arrest_Race_B','mean_Ofns_y':'Arrest_type_B'}, inplace=True)

# %%
data_comparison
# Out:
#   Borough_x  Arrest_sex_Q  Arrest_Race_Q  Arrest_type_Q  Index Borough_y  \
# 0    Queens        9708.0    2773.714286     336.508772      1     Bronx
#
#    Arrest_sex_B  Arrest_Race_B  Arrest_type_B
# 0       10599.0    3028.285714     378.142857

# %%
data_comparison[['Arrest_Race_B','Arrest_Race_Q']].plot(kind='bar')

# %%
data_comparison[['Arrest_sex_B','Arrest_sex_Q']].plot(kind='bar')

# %%
data_comparison[['Arrest_type_B','Arrest_type_Q']].plot(kind='bar')

# %% [markdown]
# ###By analyzing crime and arrest data at the New York City level, and comparing data from the Borough of Bronx and Queens, we can deduce that crimes and arrests in Bronx are higher than in Queens and this both in terms of the number of races, sex and offense.
